# %% [markdown]
# # Merging Orders and Orders Prior

# %% [markdown]
# ## Contents

# %% [markdown]
# ### 01 Importing Libraries

# %% [markdown]
# ### 02 Importing Data

# %% [markdown]
# ### 03 Merging Data

# %% [markdown]
# ### 04 Checking New Dataframe

# %% [markdown]
# ### 05 Exporting Dataframe

# %% [markdown]
# ## 01 Importing Libraries

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02 Importing Data

# %%
#creating path
path = r'C:\\Users\\samac\\Instacart Basket Analysis'

# %%
#importing final_orders_wrangled
df_ords = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_orders_wrangled.pkl'))

# %%
#importing final_orders_products_prior_wrangled
df_ords_prior = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_orders_products_prior_wrangled.pkl'))

# %%
#checking df_ords
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order  days_since_prior_order_flag
# 0                     NaN                            1
# 1                    15.0                            0
# 2                    21.0                            0
# 3                    29.0                            0
# 4                    28.0                            0

# %%
#checking df_ords_prior
df_ords_prior.head()
# Out:
#   order_id product_id  add_to_cart_order  reordered
# 0        2      33120                  1          1
# 1        2      28985                  2          1
# 2        2       9327                  3          0
# 3        2      45918                  4          1
# 4        2      30035                  5          0

# %% [markdown]
# ## 03 Merging Data

# %%
#merging df_ords and df_ords prior on 'order_id' column
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %% [markdown]
# ## 04 Checking New Dataframe

# %%
#checking df_merged_large shape
df_merged_large.shape
# Out:
# (32434489, 11)

# %%
df_merged_large.head(20)
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2539329       1             1                   2                  8
# 2   2539329       1             1                   2                  8
# 3   2539329       1             1                   2                  8
# 4   2539329       1             1                   2                  8
# 5   2398795       1             2                   3                  7
# 6   2398795       1             2                   3                  7
# 7   2398795       1             2                   3                  7
# 8   2398795       1             2                   3                  7
# 9   2398795       1             2                   3                  7
# 10  2398795       1             2                   3                  7
# 11   473747       1             3                   3                 12
# ...

# %% [markdown]
# ## 05 Exporting Dataframe

# %%
#exporting df_merged_large as 'final_orders_products_combined.pkl' pickle file

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'final_orders_products_combined.pkl'))
